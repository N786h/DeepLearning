# %% [markdown]
# <a href="https://colab.research.google.com/github/N786h/DeepLearning/blob/main/PlantDocTrainYolov8n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Download the dataset from roboflow

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="oyfXqI2vuStwUTPGdgX0")
project = rf.workspace("joseph-nelson").project("plantdoc")
dataset = project.version(4).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.134`, to intall it `pip install ultralytics==8.0.134`.
# ...
# Extracting Dataset Version Zip to PlantDoc-4 in yolov8:: 100%|██████████| 5150/5150 [00:02<00:00, 2010.74it/s]

# %% [markdown]
# #### Train Yolov8 model on custom dataset

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 616.5/616.5 kB 9.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

result = model.train(data='PlantDoc-4/data.yaml', epochs=100, batch=16)
# Out:
# Ultralytics YOLOv8.0.192 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# #### Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### Copy the Model to Google Drive

# %%
import shutil

source_path = '/content/runs/detect/train2/weights/best.pt'
destination_path = '/content/drive/MyDrive/PlantDoc-4/best.pt'

shutil.copy(source_path, destination_path)
# Out:
# '/content/drive/MyDrive/PlantDoc-4/best.pt'

# %% [markdown]
# #### Reload the Model from Google Drive

# %%
from tensorflow import keras

# Path to the model in your Google Drive
model_path = '/content/drive/MyDrive/PlantDoc-4/best.pt'

# Load the model
loaded_model = keras.models.load_model(model_path)

# %% [markdown]
# #### Reload the Model from Google Drive & predict the results

# %%
Model = YOLO("/content/drive/MyDrive/PlantDoc-4/best.pt")
results = model.predict(source="/content/PlantDoc-4/test/images", save=True, stream=True)
for result in results:
  pass
# Out:
# image 1/246 /content/PlantDoc-4/test/images/-2320-Bacterial-Spot-and-Speck_jpg.rf.9d63c6e88cb474baa4d4eab1681f6d41.jpg: 480x640 1 Tomato Septoria leaf spot, 28.5ms
# image 2/246 /content/PlantDoc-4/test/images/0000_jpg.rf.d9be28abba2b4e67431ed005bdde14de.jpg: 640x640 1 grape leaf black rot, 10.2ms
# image 3/246 /content/PlantDoc-4/test/images/000_jpg.rf.e32ba3f04d1e855e58b1b3f5475cf1e5.jpg: 480x640 (no detections), 6.7ms
# image 4/246 /content/PlantDoc-4/test/images/00_jpg.rf.567521ea9c2d0153cb8b96c5bd18e692.jpg: 480x640 1 Bell_pepper leaf spot, 2 Tomato Septoria leaf spots, 6.1ms
# image 5/246 /content/PlantDoc-4/test/images/00pe_jpg.rf.a17680fc7cdfa4c78c70f3ef1a81fd79.jpg: 640x480 1 Apple leaf, 1 Cherry leaf, 6.8ms
# image 6/246 /content/PlantDoc-4/test/images/01_jpg.rf.132567152237e39d0c9a6f61dfc88873.jpg: 512x640 1 Bell_pepper leaf, 7.2ms
# ...
